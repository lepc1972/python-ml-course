# %% [markdown]
# # data wranling - cirugia de datos

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
mainpath = "/home/lexus72/github/python-ml-course/datasets"
filename = "customer-churn-model/Customer Churn Model.txt"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath)
data
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
## crear un subconjunto de datos

# %%
Account_Length = data[("Account Length")]
Account_Length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(Account_Length)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length", "Phone", "Eve Charge", "Day Calls"]]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns = ["Account Length", "Phone", "Eve Charge", "Day Calls"]
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ["Account Length", "Vmail message", "Day Calls"]
desired_columns
# Out:
# ['Account Length', 'Vmail message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  VMail Message  Day Mins  \
# 0    KS        415  382-4657         no        yes             25     265.1
# 1    OH        415  371-7191         no        yes             26     161.6
# 2    NJ        415  358-1921         no         no              0     243.4
# 3    OH        408  375-9999        yes         no              0     299.4
# 4    OK        415  330-6626        yes         no              0     166.7
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %% [markdown]
# # filtrados alternativos 41

# %%
a = set(desired_columns)
b = set(all_columns_list)
sublist = b-a
sublist = list(sublist)
sublist
# Out:
# ['Eve Charge',
#  'Day Mins',
#  "Int'l Plan",
#  'Night Mins',
#  'VMail Plan',
#  'Phone',
#  'Day Charge',
#  'CustServ Calls',
#  'VMail Message',
#  'Eve Calls',
#  'Night Charge',
#  'Churn?',
#  'Night Calls',
#  'Eve Mins',
#  'Intl Mins',
#  'Intl Calls',
#  'State',
#  'Intl Charge',
#  'Area Code']

# %% [markdown]
# # subconjuntos de filas con ciertas condiciones 42

# %%
data[1:25] # por filas
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1     OH             107        415  371-7191         no        yes
# 2     NJ             137        415  358-1921         no         no
# 3     OH              84        408  375-9999        yes         no
# 4     OK              75        415  330-6626        yes         no
# 5     AL             118        510  391-8027        yes         no
# 6     MA             121        510  355-9993         no        yes
# 7     MO             147        415  329-9001        yes         no
# 8     LA             117        408  335-4719         no         no
# 9     WV             141        415  330-8173        yes        yes
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# ...

# %%
data1 = data[data["Day Mins"]>300]
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 76      DC              82        415  374-5353         no         no
# 156     OH              83        415  370-9116         no         no
# 197     TX             208        510  378-3625         no         no
# 230     MD              93        408  360-3324        yes         no
# 289     OK              89        510  352-6976         no         no
# 365     CO             154        415  343-5709         no         no
# 534     LA              67        510  373-6784         no         no
# 575     SD             114        415  351-7369         no        yes
# 605     MO             112        415  373-2053         no         no
# 688     MN              13        510  338-7120         no        yes
# 732     IN              48        510  342-6696         no         no
# ...

# %% [markdown]
# # data2 usuarios q son de ny

# %%
data2 = data[data["State"] == "NY"]
data2
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3219    NY             150        415  421-6268         no        yes
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %% [markdown]
# # and or dos o mas condiciones

# %%
data3 = data[(data["State"] == "NY") & (data["Day Mins"] > 300)]
data3
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 985    NY              64        415  345-9140        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 985              0     346.8         55       58.96  ...         79
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 15        27.01       160.6          128          7.23        5.4           9
# 985       21.21       275.4          102         12.39       13.3           9
#
#      Intl Charge  CustServ Calls  Churn?
# 15          1.46               4   True.
# 985         3.59               1   True.
#
# [2 rows x 21 columns]

# %%
data3.shape
# Out:
# (2, 21)

# %%
data4 = data[(data["State"] == "NY") | (data["Day Mins"] > 300)]
data4
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 76      DC              82        415  374-5353         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 156     OH              83        415  370-9116         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
# 3322    MD              62        408  409-1856         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data5 = data[data["Day Calls"]<data["Night Calls"]]
data5.shape
# Out:
# (1626, 21)

# %%
data6 = data[data["Day Mins"]<data["Night Mins"]]
data6.shape
# Out:
# (2051, 21)

# %% [markdown]
# ## minutos de dia de noche longitud de cuenta de los primeros 50 individuos

# %%
subset_first_50 = data[["Day Mins", "Night Mins", "Account Length"]][:50]
subset_first_50
subset_first_50.shape
# Out:
# (50, 3)

# %%
subset_first_50
# Out:
#     Day Mins  Night Mins  Account Length
# 0      265.1       244.7             128
# 1      161.6       254.4             107
# 2      243.4       162.6             137
# 3      299.4       196.9              84
# 4      166.7       186.9              75
# 5      223.4       203.9             118
# 6      218.2       212.6             121
# 7      157.0       211.8             147
# 8      184.5       215.8             117
# 9      258.6       326.4             141
# 10     129.1       208.8              65
# 11     187.7       196.0              74
# 12     128.8       141.1             168
# 13     156.6       192.3              95
# 14     120.7       203.0              62
# 15     332.9       160.6             161
# 16     196.4        89.3              85
# 17     190.7       129.6              93
# 18     189.7       165.7              76
# 19     224.4       192.8              73
# 20     155.1       208.8             147
# 21      62.4       209.6              77
# ...

# %%
data.iloc[1:10, 3:6] #primero filas, luego columnas iloc
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
data.iloc[:, 3:6] # todas las filas y columnas entre 3 y 6
data.iloc[1:10, :] # todas las columnas y filas de la 1 a la 10
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
## para columnas especificas

# %%
data.iloc[1:10, [2,5,7]] # para posicion iloc
# Out:
#    Area Code VMail Plan  Day Mins
# 1        415        yes     161.6
# 2        415         no     243.4
# 3        408         no     299.4
# 4        415         no     166.7
# 5        510         no     223.4
# 6        510        yes     218.2
# 7        415         no     157.0
# 8        408         no     184.5
# 9        415        yes     258.6

# %%
data.loc[[1,5,8,36], ["Area Code", "VMail Plan", "Day Mins"]] # para etiquetas loc
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %% [markdown]
# ## agregar columnas al dataset

# %%
data["Total Mins"] = data["Day Mins"] + data["Night Mins"] + data["Eve Mins"]

# %%
data["Total Mins"]
# Out:
# 0       707.2
# 1       611.5
# 2       527.2
# 3       558.2
# 4       501.9
#         ...
# 3328    650.8
# 3329    575.8
# 3330    661.5
# 3331    512.6
# 3332    741.7
# Name: Total Mins, Length: 3333, dtype: float64

# %%
data["Total Calls"] = data["Day Calls"] + data["Night Calls"] + data["Eve Calls"]

# %%
data["Total Calls"]
# Out:
# 0       300
# 1       329
# 2       328
# 3       248
# 4       356
#        ...
# 3328    286
# 3329    235
# 3330    258
# 3331    326
# 3332    272
# Name: Total Calls, Length: 3333, dtype: int64

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3         2.70
# ...

# %%
random.randrange(0,5)
# Out:
# 1
